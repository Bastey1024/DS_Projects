# %%
import pandas as pd

# %%
data={ 'apples' : [1,2,3,4,5],
        'bananas': [3,4,5,6,7]}

# %%
df = pd.DataFrame(data)

# %%
df.index=['Jan','Feb','March','April','May']

# %%
df.loc['March',['apples']]
# Out:
# apples    3
# Name: March, dtype: int64

# %%
df.to_csv('./data/applebanana.csv',)

# %%
df2=pd.read_csv('./data/applebanana.csv')

# %%
df2.head()
# Out:
#   Unnamed: 0  apples  bananas
# 0        Jan       1        3
# 1        Feb       2        4
# 2      March       3        5
# 3      April       4        6
# 4        May       5        7

# %%
df2.columns(['Month','Apples','Bananas'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-191-4c46bbcdc457> in <module>
# ----> 1 df2.columns(['Month','Apples','Bananas'])
#
# TypeError: 'Index' object is not callable

# %%
df2.replace({'Unnamed: 0':'Month'},inplace=True)

# %%
df2.set_index('Unnamed: 0', 'Month',inplace=True)

# %%
df2.index.rename('Unnamed: 0','Month')

# %%
df.describe()
# Out:
#          apples   bananas
# count  5.000000  5.000000
# mean   3.000000  5.000000
# std    1.581139  1.581139
# min    1.000000  3.000000
# 25%    2.000000  4.000000
# 50%    3.000000  5.000000
# 75%    4.000000  6.000000
# max    5.000000  7.000000
