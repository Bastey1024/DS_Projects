# %% [markdown]
# 1. What i want to know?

# %%
# Top words
# Vocabulary
# words per song

# %% [markdown]
# 2. Data Aggregation - how to aggregate?

# %%
# for every artist, select the columns with the largest value

# %% [markdown]
# 3. Visualisation - I want to know if they differ from another

# %%
# Word Clouds of vocabulary, bar plots for songs

# %%
# !pip install wordcloud
import pandas as pd
from wordcloud import WordCloud
# %matplotlib inline

data=pd.read_pickle('dtm.pkl')
data=data.transpose()  #aggregations feel easier, because only one column
# data.head()

# %%
# find the top 50 words of each band
top_dict={}
for artist in data.columns:   # for every artist, look in the df
    top=data[artist].sort_values(ascending=False).head(50)
    top_dict[artist]=list(zip(top.index,top.values))
top_dict
# Out:
# {'Blind Guardian': [('time', 141),
#   ('come', 127),
#   ('know', 110),
#   ('end', 100),
#   ('life', 90),
#   ('ba', 87),
#   ('fear', 86),
#   ('leave', 85),
#   ('feel', 78),
#   ('dark', 78),
#   ('hear', 78),
#   ('ill', 76),
#   ('dream', 75),
#   ('away', 72),
#   ('light', 70),
#   ('shall', 67),
#   ('way', 66),
#   ('oh', 66),
#   ('world', 66),
#   ('god', 64),
#   ('turn', 64),
#   ('like', 63),
#   ('wait', 63),
#   ('lose', 63),
#   ('lie', 62),
#   ('mind', 59),
#   ('far', 56),
#   ('pain', 56),
#   ('land', 55),
#   ('love', 55),
#   ('die', 55),
#   ('hand', 55),
#   ('look', 52),
#   ('night', 52),
#   ('day', 50),
#   ('fall', 49),
#   ('king', 48),
#   ('tell', 48),
#   ('let', 48),
#   ('new', 46),
#   ('hope', 43),
#   ('old', 42),
#   ('run', 42),
#   ('eye', 41),
#   ('return', 41),
#   ('change', 41),
#   ('blind', 40),
#   ('bring', 40),
#   ('welcome', 39),
#   ('believe', 38)],
#  'Iron Maiden': [('oh', 319),
#   ('know', 310),
#   ('time', 227),
#   ('man', 211),
#   ('life', 211),
#   ('come', 205),
#   ('fear', 174),
#   ('let', 169),
#   ('live', 162),
#   ('feel', 158),
#   ('run', 147),
#   ('look', 147),
#   ('away', 145),
#   ('tell', 143),
#   ('die', 139),
#   ('dream', 133),
#   ('way', 126),
#   ('like', 119),
#   ('dark', 117),
#   ('lie', 117),
#   ('want', 115),
#   ('fall', 113),
#   ('world', 111),
#   ('free', 111),
#   ('day', 108),
#   ('eye', 105),
#   ('wait', 100),
#   ('death', 94),
#   ('night', 90),
#   ('mind', 89),
#   ('bring', 88),
#   ('hear', 85),
#   ('blood', 85),
#   ('krazy', 84),
#   ('end', 84),
#   ('ill', 82),
#   ('soul', 78),
#   ('thing', 76),
#   ('god', 75),
#   ('light', 74),
#   ('think', 73),
#   ('dead', 71),
#   ('leave', 71),
#   ('hell', 69),
#   ('fight', 69),
#   ('place', 68),
#   ('jump', 66),
#   ('black', 66),
#   ('lose', 65),
#   ('love', 65)],
#  'Queen': [('love', 579),
#   ('yeah', 465),
#   ('oh', 394),
#   ('know', 309),
#   ('time', 292),
#   ('ooh', 273),
#   ('let', 243),
#   ('come', 236),
#   ('hey', 224),
#   ('want', 184),
#   ('baby', 174),
#   ('life', 173),
#   ('man', 166),
#   ('like', 164),
#   ('live', 160),
#   ('day', 157),
#   ('feel', 138),
#   ('way', 133),
#   ('la', 130),
#   ('leave', 129),
#   ('heart', 128),
#   ('good', 128),
#   ('right', 123),
#   ('need', 112),
#   ('world', 112),
#   ('hear', 106),
#   ('away', 97),
#   ('god', 93),
#   ('little', 92),
#   ('tell', 90),
#   ('night', 89),
#   ('ill', 87),
#   ('long', 86),
#   ('rock', 86),
#   ('look', 84),
#   ('say', 84),
#   ('friend', 82),
#   ('ha', 82),
#   ('lose', 81),
#   ('people', 80),
#   ('think', 78),
#   ('play', 76),
#   ('thing', 76),
#   ('fool', 76),
#   ('magic', 75),
#   ('break', 74),
#   ('hand', 73),
#   ('stop', 72),
#   ('cause', 70),
#   ('wanna', 70)],
#  'Flogging Molly': [('day', 71),
#   ('man', 62),
#   ('like', 51),
#   ('ill', 51),
#   ('leave', 50),
#   ('life', 50),
#   ('know', 48),
#   ('come', 48),
#   ('way', 45),
#   ('little', 44),
#   ('old', 43),
#   ('time', 41),
#   ('say', 40),
#   ('love', 37),
#   ('hand', 35),
#   ('heart', 35),
#   ('away', 33),
#   ('till', 33),
#   ('oh', 32),
#   ('cause', 31),
#   ('sail', 31),
#   ('yeah', 29),
#   ('eye', 28),
#   ('let', 28),
#   ('world', 26),
#   ('hell', 26),
#   ('lose', 25),
#   ('god', 25),
#   ('swing', 23),
#   ('head', 23),
#   ('shall', 23),
#   ('soon', 22),
#   ('tell', 22),
#   ('fall', 22),
#   ('wake', 22),
#   ('seven', 22),
#   ('rebel', 21),
#   ('dance', 21),
#   ('year', 20),
#   ('stand', 20),
#   ('face', 20),
#   ('break', 20),
#   ('free', 20),
#   ('good', 20),
#   ('woman', 19),
#   ('ball', 19),
#   ('soul', 19),
#   ('wrong', 19),
#   ('tear', 19),
#   ('shine', 19)],
#  'Manowar': [('fight', 113),
#   ('ride', 107),
#   ('blood', 101),
#   ('hail', 98),
#   ('metal', 97),
#   ('die', 96),
#   ('world', 71),
#   ('wind', 70),
#   ('kill', 69),
#   ('know', 68),
#   ('power', 63),
#   ('live', 62),
#   ('king', 61),
#   ('come', 58),
#   ('steel', 54),
#   ('stand', 54),
#   ('sky', 52),
#   ('hand', 50),
#   ('hear', 50),
#   ('god', 50),
#   ('wait', 46),
#   ('man', 46),
#   ('bear', 45),
#   ('heart', 42),
#   ('like', 42),
#   ('day', 41),
#   ('burn', 41),
#   ('play', 38),
#   ('sword', 37),
#   ('battle', 37),
#   ('death', 37),
#   ('night', 37),
#   ('ahha', 35),
#   ('bring', 35),
#   ('black', 34),
#   ('life', 34),
#   ('high', 33),
#   ('great', 33),
#   ('fall', 33),
#   ('time', 32),
#   ('brother', 32),
#   ('leave', 31),
#   ('hold', 31),
#   ('voulezvous', 31),
#   ('long', 30),
#   ('look', 29),
#   ('war', 29),
#   ('glory', 29),
#   ('end', 29),
#   ('fly', 29)]}

# %%
for artist,top_words in top_dict.items():    #These are first 15 Top words of each artist
    print(artist)
    print(' ,  '.join([word for word, count in top_words[0:14]]))
    print('----')
# Out:
# Blind Guardian
# time ,  come ,  know ,  end ,  life ,  ba ,  fear ,  leave ,  feel ,  dark ,  hear ,  ill ,  dream ,  away
# ----
# Iron Maiden
# oh ,  know ,  time ,  man ,  life ,  come ,  fear ,  let ,  live ,  feel ,  run ,  look ,  away ,  tell
# ----
# Queen
# love ,  yeah ,  oh ,  know ,  time ,  ooh ,  let ,  come ,  hey ,  want ,  baby ,  life ,  man ,  like
# ----
# Flogging Molly
# day ,  man ,  like ,  ill ,  leave ,  life ,  know ,  come ,  way ,  little ,  old ,  time ,  say ,  love
# ----
# Manowar
# fight ,  ride ,  blood ,  hail ,  metal ,  die ,  world ,  wind ,  kill ,  know ,  power ,  live ,  king ,  come
# ----

# %% [markdown]
# ## Oh, oooh,  etc --> Maybe stop words?
# ## Would be nice to sort by genre and spot clusters in it

# %% [markdown]
# # Visualization

# %%
word=pd.read_pickle('corpus.pkl')
word.index.rename("artist",inplace = True)
# word.transpose()
wc=WordCloud (background_color="white",colormap="Dark2", max_font_size=150,random_state=42)

# %%
import matplotlib.pyplot as plt

artists =['Blind Guardian','Iron Maiden','Queen','Flogging Molly','Manowar']

# Create a subplot wordcloud for each artist

# for i in artists:
#     wc.generate(word.Lyrics[f'{artists}'])

# for i,artist in enumerate (word.columns):
#     wc.generate(word.Lyrics)


c_manowar =WordCloud(max_font_size=50, max_words=100, colormap="Dark2", background_color="white").generate(word.Lyrics['Manowar'])

# %%
plt.imshow(c_manowar, interpolation='bilinear')
plt.axis("off")  #takes out axis
plt.title('Manowar Magic Words',  size= 30, color='orange')
plt.show()

# %% [markdown]
# # Vocabulary

# %%
# Unique Words

# %%
# non-zeros in the matrix
unique_words=[]
for artist in data.columns:
    uniques=data[artist].to_numpy().nonzero()[0].size    #nonzero is execluded in pandas since 0.24
    unique_words.append(uniques)

# %%
words=pd.DataFrame (list(zip(artists,unique_words)),columns=['Artist','Unique Words'])

# %%
words.set_index('Artist').sort_values('Unique Words', ascending = False)
# Out:
#                 Unique Words
# Artist
# Iron Maiden             3098
# Queen                   2904
# Blind Guardian          1782
# Flogging Molly          1475
# Manowar                 1455

# %%
import os
songs_per_artist=[]
for artist in artists:
    DIR = f'./data/{artist}'
    songs=len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
    songs_per_artist.append(songs)

# %%
words= word['Lyrics'].str.split().apply(len).value_counts()

# %%
word
# Out:
#                                                            Lyrics  Word Count
# artist
# Blind Guardian  oh not blindness decay circle close song end h...         NaN
# Iron Maiden     work sit beer turn late night tv wonder be mea...         NaN
# Queen           year assemble volunteer day land ship sail blu...         NaN
# Flogging Molly  wipe blood lip flesh hand s thorn leave grow l...         NaN
# Manowar         chariot run ship ill drive sea come gold wall ...         NaN
